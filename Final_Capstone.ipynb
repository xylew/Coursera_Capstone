# %% [markdown]
# # Setting up the enviroment #

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          90 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.20.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# # Importing New York Data Set #

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
# Out:
# Data downloaded!

# %%
neighborhoods_data = newyork_data['features']
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
neighborhoods = pd.DataFrame(columns=column_names)
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %% [markdown]
# # Creating the map of NY #

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.5,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Connecting to Foursquare #

# %%
CLIENT_ID = 'QX1RISY1NCHO3XIXWBFYJVJ0I2DMHNSQ4QKGMKGDK2MROOTR' # your Foursquare ID
CLIENT_SECRET = 'HGGI2E30BHU0ZAL0QYLGD0UMU1MQJXJHCX24OU2UE410LDMP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# %% [markdown]
# # Categorizing venue type #

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
ny_venues = getNearbyVenues(names=neighborhoods['Neighborhood'],
                                   latitudes=neighborhoods['Latitude'],
                                   longitudes=neighborhoods['Longitude']
                                  )
ny_venues.groupby('Neighborhood').count()
# one hot encoding
ny_onehot = pd.get_dummies(ny_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
ny_onehot['Neighborhood'] = ny_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [ny_onehot.columns[-1]] + list(ny_onehot.columns[:-1])
ny_onehot = ny_onehot[fixed_columns]
# Out:
# Wakefield
# Co-op City
# Eastchester
# Fieldston
# Riverdale
# Kingsbridge
# Marble Hill
# Woodlawn
# Norwood
# Williamsbridge
# Baychester
# Pelham Parkway
# City Island
# Bedford Park
# University Heights
# Morris Heights
# Fordham
# East Tremont
# West Farms
# High  Bridge
# Melrose
# Mott Haven
# Port Morris
# Longwood
# Hunts Point
# Morrisania
# Soundview
# Clason Point
# Throgs Neck
# Country Club
# Parkchester
# Westchester Square
# Van Nest
# Morris Park
# Belmont
# Spuyten Duyvil
# North Riverdale
# Pelham Bay
# Schuylerville
# Edgewater Park
# Castle Hill
# Olinville
# Pelham Gardens
# Concourse
# Unionport
# Edenwald
# Bay Ridge
# Bensonhurst
# Sunset Park
# Greenpoint
# Gravesend
# Brighton Beach
# Sheepshead Bay
# Manhattan Terrace
# Flatbush
# Crown Heights
# East Flatbush
# Kensington
# Windsor Terrace
# Prospect Heights
# Brownsville
# Williamsburg
# Bushwick
# Bedford Stuyvesant
# Brooklyn Heights
# Cobble Hill
# Carroll Gardens
# Red Hook
# Gowanus
# Fort Greene
# Park Slope
# Cypress Hills
# East New York
# Starrett City
# Canarsie
# Flatlands
# Mill Island
# Manhattan Beach
# Coney Island
# Bath Beach
# Borough Park
# Dyker Heights
# Gerritsen Beach
# Marine Park
# Clinton Hill
# Sea Gate
# Downtown
# Boerum Hill
# Prospect Lefferts Gardens
# Ocean Hill
# City Line
# Bergen Beach
# Midwood
# Prospect Park South
# Georgetown
# East Williamsburg
# North Side
# South Side
# Ocean Parkway
# Fort Hamilton
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Astoria
# Woodside
# Jackson Heights
# Elmhurst
# Howard Beach
# Corona
# Forest Hills
# Kew Gardens
# Richmond Hill
# Flushing
# Long Island City
# Sunnyside
# East Elmhurst
# Maspeth
# Ridgewood
# Glendale
# Rego Park
# Woodhaven
# Ozone Park
# South Ozone Park
# College Point
# Whitestone
# Bayside
# Auburndale
# Little Neck
# Douglaston
# Glen Oaks
# Bellerose
# Kew Gardens Hills
# Fresh Meadows
# Briarwood
# Jamaica Center
# Oakland Gardens
# Queens Village
# Hollis
# South Jamaica
# St. Albans
# Rochdale
# Springfield Gardens
# Cambria Heights
# Rosedale
# Far Rockaway
# Broad Channel
# Breezy Point
# Steinway
# Beechhurst
# Bay Terrace
# Edgemere
# Arverne
# Rockaway Beach
# Neponsit
# Murray Hill
# Floral Park
# Holliswood
# Jamaica Estates
# Queensboro Hill
# Hillcrest
# Ravenswood
# Lindenwood
# Laurelton
# Lefrak City
# Belle Harbor
# Rockaway Park
# Somerville
# Brookville
# Bellaire
# North Corona
# Forest Hills Gardens
# St. George
# New Brighton
# Stapleton
# Rosebank
# West Brighton
# Grymes Hill
# Todt Hill
# South Beach
# Port Richmond
# Mariner's Harbor
# Port Ivory
# Castleton Corners
# New Springville
# Travis
# New Dorp
# Oakwood
# Great Kills
# Eltingville
# Annadale
# Woodrow
# Tottenville
# Tompkinsville
# Silver Lake
# Sunnyside
# Ditmas Park
# Wingate
# Rugby
# Park Hill
# Westerleigh
# Graniteville
# Arlington
# Arrochar
# Grasmere
# Old Town
# Dongan Hills
# Midland Beach
# Grant City
# New Dorp Beach
# Bay Terrace
# Huguenot
# Pleasant Plains
# Butler Manor
# Charleston
# Rossville
# Arden Heights
# Greenridge
# Heartland Village
# Chelsea
# Bloomfield
# Bulls Head
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Richmond Town
# Shore Acres
# Clifton
# Concord
# Emerson Hill
# Randall Manor
# Howland Hook
# Elm Park
# Remsen Village
# New Lots
# Paerdegat Basin
# Mill Basin
# Jamaica Hills
# Utopia
# Pomonok
# Astoria Heights
# Claremont Village
# Concourse Village
# Mount Eden
# Mount Hope
# Sutton Place
# Hunters Point
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Sunnyside Gardens
# Blissville
# Fulton Ferry
# Vinegar Hill
# Weeksville
# Broadway Junction
# Dumbo
# Manor Heights
# Willowbrook
# Sandy Ground
# Egbertville
# Roxbury
# Homecrest
# Middle Village
# Prince's Bay
# Lighthouse Hill
# Richmond Valley
# Malba
# Highland Park
# Madison
# Bronxdale
# Allerton
# Kingsbridge Heights
# Erasmus
# Hudson Yards
# Hammels
# Bayswater
# Queensbridge
# Fox Hills

# %%
ny_grouped = ny_onehot.groupby('Neighborhood').mean().reset_index()

# %%
num_top_venues = 30

for hood in ny_grouped['Neighborhood']:
    temp = ny_grouped[ny_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = ny_grouped['Neighborhood']

for ind in np.arange(ny_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(ny_grouped.iloc[ind, :], num_top_venues)

# %%
# set number of clusters
kclusters = 5

ny_grouped_clustering = ny_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(ny_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:50]
# Out:
# array([1, 1, 0, 0, 1, 4, 4, 2, 4, 1, 4, 4, 4, 1, 4, 4, 1, 4, 1, 2, 4, 1,
#        1, 4, 4, 1, 0, 4, 1, 0, 1, 4, 1, 1, 1, 4, 1, 4, 1, 4, 0, 4, 2, 4,
#        4, 1, 1, 4, 4, 4], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

ny_merged = ny_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
ny_merged = ny_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

ny_merged.head() # check the last columns!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-b63bb832ebce> in <module>
#       2 neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
#       3
# ----> 4 ny_merged = ny_data
#       5
#       6 # merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
#
# NameError: name 'ny_data' is not defined

# %%
ny_merged['Cluster Labels'] = ny_merged['Cluster Labels'].fillna(0).astype(np.int64)
ny_merged.dtypes
# Out:
# Borough                   object
# Neighborhood              object
# Latitude                 float64
# Longitude                float64
# Cluster Labels             int64
# 1st Most Common Venue     object
# 2nd Most Common Venue     object
# 3rd Most Common Venue     object
# 4th Most Common Venue     object
# 5th Most Common Venue     object
# dtype: object

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(ny_merged['Latitude'], ny_merged['Longitude'], ny_merged['Neighborhood'], ny_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Identifying clusters defined by a cafe as its most top venue #

# %%
ny_merged.loc[ny_merged['Cluster Labels'] == 0, ny_merged.columns[[1] + list(range(5, ny_merged.shape[1]))]]
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 77   Manhattan Beach              Bus Stop        Sandwich Place
# 172     Breezy Point                 Trail              Bus Stop
# 198     New Brighton              Bus Stop                  Park
# 202      Grymes Hill              Bus Stop               Dog Run
# 204      South Beach                 Beach                  Pier
# 207       Port Ivory                   NaN                   NaN
# 212          Oakwood                   Bar           Bus Station
# 224        Park Hill              Bus Stop           Coffee Shop
# 227        Arlington          Intersection   American Restaurant
# 238     Butler Manor                  Pool        Baseball Field
# 241    Arden Heights           Coffee Shop              Bus Stop
# 242       Greenridge            Bagel Shop                 Diner
# 245       Bloomfield     Recreation Center            Theme Park
# 256    Randall Manor              Bus Stop                  Park
# 257     Howland Hook                   NaN                   NaN
# 285      Willowbrook              Bus Stop            Bagel Shop
# 286     Sandy Ground              Bus Stop          Intersection
# 305        Fox Hills             BBQ Joint          Cocktail Bar
#
#     3rd Most Common Venue 4th Most Common Venue   5th Most Common Venue
# 77             Playground                 Beach          Ice Cream Shop
# 172                 Beach            Board Shop     Monument / Landmark
# 198     Convenience Store         Bowling Alley          Discount Store
# 202         Women's Store               Factory      Falafel Restaurant
# 204         Deli / Bodega              Bus Stop      Athletics & Sports
# 207                   NaN                   NaN                     NaN
# 212              Bus Stop           Flower Shop                 Factory
# 224                 Hotel    Athletics & Sports    Gym / Fitness Center
# 227              Bus Stop         Grocery Store           Women's Store
# 238     Convenience Store              Bus Stop  Furniture / Home Store
# 241           Pizza Place              Pharmacy           Women's Store
# 242              Bus Stop           Pizza Place           Women's Store
# 245                  Park        Discount Store                Bus Stop
# 256            Bagel Shop         Women's Store             Flea Market
# 257                   NaN                   NaN                     NaN
# 285      Greek Restaurant         Women's Store             Flower Shop
# 286                Market  Fast Food Restaurant             Art Gallery
# 305              Bus Stop   American Restaurant          Sandwich Place

# %%
ny_merged.loc[ny_merged['Cluster Labels'] == 1, ny_merged.columns[[1] + list(range(5, ny_merged.shape[1]))]]
# Out:
#             Neighborhood      1st Most Common Venue  \
# 0              Wakefield                 Laundromat
# 1             Co-op City                       Park
# 2            Eastchester       Caribbean Restaurant
# 5            Kingsbridge                Pizza Place
# 6            Marble Hill                Coffee Shop
# 7               Woodlawn              Deli / Bodega
# 8                Norwood                Pizza Place
# 10            Baychester                 Donut Shop
# 11        Pelham Parkway              Deli / Bodega
# 13          Bedford Park                      Diner
# 14    University Heights         Chinese Restaurant
# 16               Fordham                Pizza Place
# 17          East Tremont                Pizza Place
# 20               Melrose                Pizza Place
# 21            Mott Haven                Pizza Place
# 23              Longwood             Sandwich Place
# 25            Morrisania                Bus Station
# 31    Westchester Square       Fast Food Restaurant
# 32              Van Nest              Deli / Bodega
# 33           Morris Park                Pizza Place
# 34               Belmont         Italian Restaurant
# 35        Spuyten Duyvil                       Park
# 36       North Riverdale                Pizza Place
# 37            Pelham Bay         Italian Restaurant
# 38         Schuylerville                        Bar
# 39        Edgewater Park         Italian Restaurant
# 40           Castle Hill                       Bank
# 43             Concourse              Deli / Bodega
# 44             Unionport                 Donut Shop
# 48           Sunset Park                Pizza Place
# 50             Gravesend                Pizza Place
# 53     Manhattan Terrace                Pizza Place
# 54              Flatbush                       Bank
# 55         Crown Heights                Pizza Place
# 71         Cypress Hills        Fried Chicken Joint
# 72         East New York         Chinese Restaurant
# 73         Starrett City                   Pharmacy
# 75             Flatlands                   Pharmacy
# 79            Bath Beach         Chinese Restaurant
# 80          Borough Park                       Bank
# 82       Gerritsen Beach             Ice Cream Shop
# 83           Marine Park                        Gym
# 89            Ocean Hill              Deli / Bodega
# 90             City Line                 Donut Shop
# 92               Midwood                Pizza Place
# 93   Prospect Park South       Caribbean Restaurant
# 94            Georgetown                       Bank
# 134               Corona                     Bakery
# 135         Forest Hills       Gym / Fitness Center
# 136          Kew Gardens              Deli / Bodega
# 137        Richmond Hill  Latin American Restaurant
# 141        East Elmhurst                 Donut Shop
# 142              Maspeth                      Diner
# 144             Glendale        Arts & Crafts Store
# 146            Woodhaven              Deli / Bodega
# 147           Ozone Park                Pizza Place
# 148     South Ozone Park                       Park
# 149        College Point              Deli / Bodega
# 150           Whitestone            Bubble Tea Shop
# 154           Douglaston              Deli / Bodega
# 155            Glen Oaks                   Pharmacy
# 156            Bellerose                Pizza Place
# 157    Kew Gardens Hills                       Bank
# 159            Briarwood              Deli / Bodega
# 161      Oakland Gardens          Korean Restaurant
# 162       Queens Village                       Bank
# 165           St. Albans       Caribbean Restaurant
# 166             Rochdale                     Market
# 170         Far Rockaway                Pizza Place
# 171        Broad Channel              Deli / Bodega
# 174           Beechhurst                Yoga Studio
# 176             Edgemere                Pizza Place
# 185            Hillcrest                 Food Truck
# 187           Lindenwood                       Bank
# 191        Rockaway Park                      Beach
# 193           Brookville              Deli / Bodega
# 195         North Corona              Deli / Bodega
# 199            Stapleton                       Bank
# 205        Port Richmond                 Donut Shop
# 206     Mariner's Harbor         Italian Restaurant
# 208    Castleton Corners                Pizza Place
# 209      New Springville          Mobile Phone Shop
# 210               Travis                      Hotel
# 214          Eltingville                Pizza Place
# 215             Annadale                Pizza Place
# 216              Woodrow                   Pharmacy
# 221          Ditmas Park              Deli / Bodega
# 222              Wingate       Fast Food Restaurant
# 223                Rugby                       Bank
# 228             Arrochar              Deli / Bodega
# 230             Old Town         Italian Restaurant
# 231         Dongan Hills                   Pharmacy
# 232        Midland Beach                 Restaurant
# 233           Grant City                Pizza Place
# 234       New Dorp Beach         Italian Restaurant
# 236             Huguenot                Bridal Shop
# 237      Pleasant Plains                 Donut Shop
# 240            Rossville                Pizza Place
# 243    Heartland Village              Shopping Mall
# 246           Bulls Head                   Bus Stop
# 258             Elm Park             Ice Cream Shop
# 259       Remsen Village       Caribbean Restaurant
# 260             New Lots                Pizza Place
# 262           Mill Basin                Pizza Place
# 263        Jamaica Hills        Fried Chicken Joint
# 264               Utopia              Deli / Bodega
# 268    Concourse Village              Deli / Bodega
# 269           Mount Eden                Pizza Place
# 270           Mount Hope              Deli / Bodega
# 278           Blissville                      Hotel
# 282    Broadway Junction                      Diner
# 284        Manor Heights                 Campground
# 289            Homecrest                       Bank
# 291         Prince's Bay         Italian Restaurant
# 293      Richmond Valley       Fast Food Restaurant
# 295        Highland Park                Pizza Place
# 296              Madison                 Bagel Shop
# 297            Bronxdale         Italian Restaurant
# 298             Allerton                Pizza Place
# 299  Kingsbridge Heights                Pizza Place
# 300              Erasmus       Caribbean Restaurant
#
#                2nd Most Common Venue       3rd Most Common Venue  \
# 0                           Pharmacy                  Donut Shop
# 1                         Restaurant                 Bus Station
# 2                      Deli / Bodega                 Bus Station
# 5                                Bar              Sandwich Place
# 6                     Sandwich Place              Discount Store
# 7                                Bar                         Pub
# 8                               Park                        Bank
# 10                       Music Venue         Fried Chicken Joint
# 11                Italian Restaurant                 Pizza Place
# 13                     Deli / Bodega                 Pizza Place
# 14               Fried Chicken Joint                      Bakery
# 16                 Mobile Phone Shop                  Donut Shop
# 17                              Café                 Supermarket
# 20                          Pharmacy                 Supermarket
# 21                     Deli / Bodega          Spanish Restaurant
# 23              Fast Food Restaurant               Grocery Store
# 25                    Discount Store                  Donut Shop
# 31                       Pizza Place                    Pharmacy
# 32                       Pizza Place                         Spa
# 33                            Bakery               Deli / Bodega
# 34                       Pizza Place               Deli / Bodega
# 35                              Bank                Intersection
# 36                              Bank               Deli / Bodega
# 37                              Bank        Fast Food Restaurant
# 38                Mexican Restaurant                    Pharmacy
# 39                     Deli / Bodega          Chinese Restaurant
# 40                    Cosmetics Shop                      Market
# 43                Spanish Restaurant                        Food
# 44         Latin American Restaurant                       Plaza
# 48         Latin American Restaurant                        Bank
# 50                       Bus Station                      Lounge
# 53                        Bagel Shop                  Donut Shop
# 54                       Coffee Shop        Caribbean Restaurant
# 55                            Museum                        Café
# 71         Latin American Restaurant                  Donut Shop
# 72                     Deli / Bodega        Fast Food Restaurant
# 73                     Shopping Mall                  Donut Shop
# 75               Fried Chicken Joint        Fast Food Restaurant
# 79                       Pizza Place                    Pharmacy
# 80                       Pizza Place                    Pharmacy
# 82                       Pizza Place                         Bar
# 83                      Soccer Field               Deli / Bodega
# 89                          Bus Stop               Grocery Store
# 90               Fried Chicken Joint                 Pizza Place
# 92                Italian Restaurant            Video Game Store
# 93                       Pizza Place        Fast Food Restaurant
# 94                          Pharmacy              Breakfast Spot
# 134               Mexican Restaurant   South American Restaurant
# 135                              Gym                 Yoga Studio
# 136               Chinese Restaurant                   Pet Store
# 137                    Deli / Bodega                        Bank
# 141                   Ice Cream Shop         Rental Car Location
# 142                      Pizza Place               Grocery Store
# 144                          Brewery                 Pizza Place
# 146                         Pharmacy                        Bank
# 147                              Gym                        Bank
# 148                    Deli / Bodega                         Bar
# 149               Chinese Restaurant                Dessert Shop
# 150                    Deli / Bodega                       Train
# 154                             Bank          Chinese Restaurant
# 155                 Department Store                   Gift Shop
# 156                    Deli / Bodega          Italian Restaurant
# 157                       Playground                 Bus Station
# 159                Indian Restaurant           Convenience Store
# 161               Chinese Restaurant                 Yoga Studio
# 162              Fried Chicken Joint                  Donut Shop
# 165             Fast Food Restaurant               Deli / Bodega
# 166  Southern / Soul Food Restaurant                   Pet Store
# 170                    Deli / Bodega               Grocery Store
# 171                      Pizza Place             Other Nightlife
# 174                      Supermarket        Gym / Fitness Center
# 176                    Metro Station            Asian Restaurant
# 185                    Grocery Store                  Donut Shop
# 187                       Donut Shop                         Gym
# 191                      Pizza Place                        Bank
# 193                           Market               Women's Store
# 195                           Bakery          Spanish Restaurant
# 199                       Restaurant          Mexican Restaurant
# 205                             Food           Martial Arts Dojo
# 206                    Deli / Bodega              Nightlife Spot
# 208              Japanese Restaurant              Ice Cream Shop
# 209          Health & Beauty Service                    Pharmacy
# 210                    Deli / Bodega               Bowling Alley
# 214                 Sushi Restaurant          Italian Restaurant
# 215                           Bakery                  Bagel Shop
# 216               Italian Restaurant                 Pizza Place
# 221                       Kids Store                 Pizza Place
# 222                    Deli / Bodega         Rental Car Location
# 223             Caribbean Restaurant              Sandwich Place
# 228               Italian Restaurant                    Bus Stop
# 230                      Pizza Place                        Bank
# 231                       Bagel Shop          Italian Restaurant
# 232                            Beach                   Pet Store
# 233                 Asian Restaurant      Furniture / Home Store
# 234                    Deli / Bodega                Skating Rink
# 236                   Ice Cream Shop                  Nail Salon
# 237                   Discount Store                        Bank
# 240                       Bagel Shop               Deli / Bodega
# 243                        Bookstore     Health & Beauty Service
# 246                    Deli / Bodega          Chinese Restaurant
# 258              American Restaurant                 Pizza Place
# 259             Fast Food Restaurant            Asian Restaurant
# 260               Chinese Restaurant               Grocery Store
# 262               Chinese Restaurant          Italian Restaurant
# 263             Fast Food Restaurant           Indian Restaurant
# 264                 Basketball Court   South American Restaurant
# 268               Mexican Restaurant        Fast Food Restaurant
# 269                         Pharmacy        Fast Food Restaurant
# 270               Chinese Restaurant              Sandwich Place
# 278                    Deli / Bodega                 Bus Station
# 282                       Donut Shop                    Bus Stop
# 284                    Deli / Bodega                  Donut Shop
# 289                       Donut Shop                        Café
# 291                      Pizza Place            Sushi Restaurant
# 293                    Deli / Bodega  Construction & Landscaping
# 295                     Liquor Store               Deli / Bodega
# 296                    Deli / Bodega                 Bus Station
# 297                    Deli / Bodega             Doctor's Office
# 298                      Supermarket          Chinese Restaurant
# 299               Mexican Restaurant          Spanish Restaurant
# 300                      Yoga Studio                  Playground
#
#                4th Most Common Venue      5th Most Common Venue
# 0                        Gas Station             Sandwich Place
# 1               Fast Food Restaurant                   Pharmacy
# 2                              Diner                   Bus Stop
# 5          Latin American Restaurant             Discount Store
# 6                        Yoga Studio                Pizza Place
# 7                        Pizza Place                 Playground
# 8                      Deli / Bodega                   Pharmacy
# 10                Spanish Restaurant                Supermarket
# 11                             Plaza                Bus Station
# 13               Fried Chicken Joint                Supermarket
# 14                       Pizza Place              Jewelry Store
# 16              Fast Food Restaurant       Gym / Fitness Center
# 17                            Lounge          Paella Restaurant
# 20                  Department Store            Supplement Shop
# 21                               Gym                 Donut Shop
# 23                  Community Center  Latin American Restaurant
# 25                     Metro Station              Grocery Store
# 31                        Donut Shop           Department Store
# 32                        Hookah Bar                     Bakery
# 33                      Burger Joint                Bus Station
# 34                            Bakery                       Bank
# 35                          Pharmacy                   Bus Line
# 36                Italian Restaurant                Bus Station
# 37                    Sandwich Place       Gym / Fitness Center
# 38                              Bank                Pizza Place
# 39                       Coffee Shop                Pizza Place
# 40                       Pizza Place  Latin American Restaurant
# 43                            Bakery    Health & Beauty Service
# 44                    Ice Cream Shop                Pizza Place
# 48                            Bakery         Mexican Restaurant
# 50                            Bakery         Italian Restaurant
# 53                    Ice Cream Shop            Organic Grocery
# 54                Mexican Restaurant             Sandwich Place
# 55                        Bagel Shop              Deli / Bodega
# 71              Fast Food Restaurant              Metro Station
# 72                Spanish Restaurant              Event Service
# 73                       Supermarket                      River
# 75              Caribbean Restaurant                     Lounge
# 79                        Donut Shop       Fast Food Restaurant
# 80                     Deli / Bodega                      Hotel
# 82                       Gas Station           Department Store
# 83                    Baseball Field           Basketball Court
# 89   Southern / Soul Food Restaurant                 Playground
# 90                        Shoe Store               Optical Shop
# 92                       Candy Store              Metro Station
# 93                 Mobile Phone Shop                   Pharmacy
# 94                        Bagel Shop                 Donut Shop
# 134                   Ice Cream Shop               Liquor Store
# 135                Convenience Store                Pizza Place
# 136                   Cosmetics Shop                       Bank
# 137             Caribbean Restaurant                     Lounge
# 141                        Hotel Bar               Home Service
# 142                Mobile Phone Shop             Discount Store
# 144                Food & Drink Shop              Women's Store
# 146              Fried Chicken Joint                Supermarket
# 147                            Diner                   Pharmacy
# 148             Fast Food Restaurant               Home Service
# 149                      Pizza Place                        Bar
# 150                    Moving Target                Flower Shop
# 154                           Bakery                Supermarket
# 155               Mexican Restaurant             Clothing Store
# 156                      Flower Shop         Chinese Restaurant
# 157                      Pizza Place           Sushi Restaurant
# 159                            Plaza         Mexican Restaurant
# 161                       Donut Shop                Supermarket
# 162                Mobile Phone Shop           Pedestrian Plaza
# 165               Seafood Restaurant              Grocery Store
# 166                       Laundromat         Chinese Restaurant
# 170               Chinese Restaurant                Bus Station
# 171                         Dive Bar                       Park
# 174                              Gym               Optical Shop
# 176                   Scenic Lookout                  Gift Shop
# 185                    Deli / Bodega                       Food
# 187                             Park                     Bakery
# 191                         Pharmacy                 Donut Shop
# 193                      Flea Market                    Exhibit
# 195             Gym / Fitness Center                Pizza Place
# 199                    Deli / Bodega                Pizza Place
# 205                      Pizza Place                        Bar
# 206                         Bus Stop          Other Repair Shop
# 208                   Hardware Store               Burger Joint
# 209                       Donut Shop              Grocery Store
# 210               Spanish Restaurant                       Park
# 214                         Pharmacy                      Diner
# 215                 Sushi Restaurant                 Sports Bar
# 216                 Sushi Restaurant              Grocery Store
# 221             Caribbean Restaurant         Chinese Restaurant
# 222                       Donut Shop                   Pharmacy
# 223                      Supermarket       Fast Food Restaurant
# 228                            Hotel   Mediterranean Restaurant
# 230                    Grocery Store               Liquor Store
# 231                      Pizza Place                       Bank
# 232                         Bus Stop         Chinese Restaurant
# 233                        BBQ Joint              Grocery Store
# 234                       Restaurant                      Beach
# 236                    Train Station             Sandwich Place
# 237             Fast Food Restaurant                Pizza Place
# 240                Convenience Store                   Pharmacy
# 243                         Pharmacy                        Gym
# 246                      Pizza Place             Ice Cream Shop
# 258                         Bus Stop         Chinese Restaurant
# 259                      Fish Market                 Donut Shop
# 260                    Deli / Bodega                       Bank
# 262                    Grocery Store        Japanese Restaurant
# 263                       Donut Shop                   Pharmacy
# 264               Chinese Restaurant                       Park
# 268                   Sandwich Place        Sporting Goods Shop
# 269                    Grocery Store          Mobile Phone Shop
# 270                    Grocery Store             Ice Cream Shop
# 278                       Donut Shop                Art Gallery
# 282               Mexican Restaurant              Deli / Bodega
# 284                             Food               Liquor Store
# 289                    Grocery Store         Mexican Restaurant
# 291               Chinese Restaurant               Liquor Store
# 293                    Smoothie Shop                       Food
# 295                           Garden                Supermarket
# 296                   Pilates Studio                Candy Store
# 297            Performing Arts Venue         Mexican Restaurant
# 298                           Bakery                        Spa
# 299                      Bus Station        Fried Chicken Joint
# 300                    Grocery Store       Gym / Fitness Center

# %%
ny_merged.loc[ny_merged['Cluster Labels'] == 2, ny_merged.columns[[1] + list(range(5, ny_merged.shape[1]))]]
# Out:
#             Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 4              Riverdale           Bus Station                  Park
# 15        Morris Heights           Bus Station              Pharmacy
# 18            West Farms           Bus Station            Donut Shop
# 19          High  Bridge    Chinese Restaurant        Sandwich Place
# 26             Soundview    Chinese Restaurant          Liquor Store
# 30           Parkchester           Supermarket           Pizza Place
# 41             Olinville   Fried Chicken Joint  Caribbean Restaurant
# 42        Pelham Gardens    Chinese Restaurant           Bus Station
# 45              Edenwald           Gas Station           Supermarket
# 56         East Flatbush                  Park    Chinese Restaurant
# 74              Canarsie                   Gym      Asian Restaurant
# 158        Fresh Meadows           Bus Station    Chinese Restaurant
# 164        South Jamaica           Bus Station        Shop & Service
# 167  Springfield Gardens   Fried Chicken Joint           Bus Station
# 169             Rosedale         Jewelry Store        Cosmetics Shop
# 182           Holliswood            Donut Shop           Supermarket
# 184      Queensboro Hill    Chinese Restaurant                  Bank
# 194             Bellaire    Chinese Restaurant         Deli / Bodega
# 226         Graniteville           Supermarket            Food Truck
# 261      Paerdegat Basin    Chinese Restaurant    Child Care Service
# 266      Astoria Heights         Deli / Bodega                 Plaza
# 267    Claremont Village         Grocery Store           Bus Station
#
#       3rd Most Common Venue       4th Most Common Venue 5th Most Common Venue
# 4                      Bank                       Plaza            Food Truck
# 15            Moving Target               Grocery Store    Spanish Restaurant
# 18                 Bus Stop                  Playground        Scenic Lookout
# 19       Seafood Restaurant                    Pharmacy           Pizza Place
# 26         Basketball Court         Fried Chicken Joint           Bus Station
# 30            Women's Store         American Restaurant      Asian Restaurant
# 41   Furniture / Home Store                  Laundromat         Metro Station
# 42                 Pharmacy                  Donut Shop                  Café
# 45              Bus Station                 Fish Market         Grocery Store
# 56         Department Store                      Bakery           Supermarket
# 74          Thai Restaurant        Caribbean Restaurant    Chinese Restaurant
# 158                Pharmacy  Construction & Landscaping         Moving Target
# 164           Grocery Store                      Bakery           Supermarket
# 167              Donut Shop                  Laundromat           Gas Station
# 169            Liquor Store        Caribbean Restaurant            Smoke Shop
# 182       Mobile Phone Shop                  Playground         Women's Store
# 184                  Bakery            Asian Restaurant           Bus Station
# 194             Bus Station               Moving Target     Convenience Store
# 226           Women's Store                 Flea Market               Exhibit
# 261        Asian Restaurant                        Food         Women's Store
# 266             Bus Station                 Supermarket         Bowling Alley
# 267      Chinese Restaurant        Caribbean Restaurant          Liquor Store

# %%
ny_merged.loc[ny_merged['Cluster Labels'] == 3, ny_merged.columns[[1] + list(range(5, ny_merged.shape[1]))]]
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 192   Somerville                  Park         Women's Store
# 203    Todt Hill                  Park         Women's Store
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 192           Flea Market               Exhibit               Factory
# 203           Flea Market               Exhibit               Factory

# %%
ny_merged.loc[ny_merged['Cluster Labels'] == 4, ny_merged.columns[[1] + list(range(5, ny_merged.shape[1]))]]
# Out:
#                   Neighborhood       1st Most Common Venue  \
# 3                    Fieldston                       River
# 9               Williamsbridge                         Bar
# 12                 City Island             Harbor / Marina
# 22                 Port Morris   Latin American Restaurant
# 24                 Hunts Point                        Bank
# 27                Clason Point                        Park
# 28                 Throgs Neck                 Coffee Shop
# 29                Country Club              Sandwich Place
# 46                   Bay Ridge          Italian Restaurant
# 47                 Bensonhurst               Grocery Store
# 49                  Greenpoint                         Bar
# 51              Brighton Beach          Russian Restaurant
# 52              Sheepshead Bay                Dessert Shop
# 57                  Kensington               Grocery Store
# 58             Windsor Terrace                       Diner
# 59            Prospect Heights                         Bar
# 60                 Brownsville                  Restaurant
# 61                Williamsburg                 Coffee Shop
# 62                    Bushwick                         Bar
# 63          Bedford Stuyvesant               Deli / Bodega
# 64            Brooklyn Heights                 Yoga Studio
# 65                 Cobble Hill                         Bar
# 66             Carroll Gardens          Italian Restaurant
# 67                    Red Hook          Seafood Restaurant
# 68                     Gowanus                         Bar
# 69                 Fort Greene          Italian Restaurant
# 70                  Park Slope                Burger Joint
# 76                 Mill Island                        Lake
# 78                Coney Island            Baseball Stadium
# 81               Dyker Heights                Dance Studio
# 84                Clinton Hill          Italian Restaurant
# 85                    Sea Gate                Optical Shop
# 86                    Downtown                Burger Joint
# 87                 Boerum Hill                Dance Studio
# 88   Prospect Lefferts Gardens                        Café
# 91                Bergen Beach             Harbor / Marina
# 95           East Williamsburg                         Bar
# 96                  North Side                 Coffee Shop
# 97                  South Side                         Bar
# 98               Ocean Parkway                  Steakhouse
# 99               Fort Hamilton                    Pharmacy
# 100                  Chinatown          Chinese Restaurant
# 101         Washington Heights                        Café
# 102                     Inwood                        Café
# 103           Hamilton Heights                 Pizza Place
# 104             Manhattanville                 Coffee Shop
# 105             Central Harlem                         Bar
# 106                East Harlem          Mexican Restaurant
# 107            Upper East Side          Italian Restaurant
# 108                  Yorkville                 Coffee Shop
# 109                 Lenox Hill                 Coffee Shop
# 110           Roosevelt Island                 Coffee Shop
# 111            Upper West Side          Italian Restaurant
# 112             Lincoln Square        Gym / Fitness Center
# 113                    Clinton                     Theater
# 114                    Midtown                       Hotel
# 115                Murray Hill           Korean Restaurant
# 116                    Chelsea                 Coffee Shop
# 117          Greenwich Village          Italian Restaurant
# 118               East Village                         Bar
# 119            Lower East Side                 Coffee Shop
# 120                    Tribeca                        Park
# 121               Little Italy                      Bakery
# 122                       Soho              Clothing Store
# 123               West Village          Italian Restaurant
# 124           Manhattan Valley           Indian Restaurant
# 125        Morningside Heights                   Bookstore
# 126                   Gramercy          Italian Restaurant
# 127          Battery Park City                        Park
# 128         Financial District                 Coffee Shop
# 129                    Astoria                         Bar
# 130                   Woodside               Grocery Store
# 131            Jackson Heights   Latin American Restaurant
# 132                   Elmhurst             Thai Restaurant
# 133               Howard Beach          Italian Restaurant
# 138                   Flushing           Hotpot Restaurant
# 139           Long Island City                 Coffee Shop
# 140                  Sunnyside                 Pizza Place
# 143                  Ridgewood            Greek Restaurant
# 145                  Rego Park                      Bakery
# 151                    Bayside                         Bar
# 152                 Auburndale          Italian Restaurant
# 153                Little Neck          Chinese Restaurant
# 160             Jamaica Center           Mobile Phone Shop
# 163                     Hollis              Sandwich Place
# 168            Cambria Heights        Caribbean Restaurant
# 173                   Steinway         Rental Car Location
# 175                Bay Terrace              Clothing Store
# 177                    Arverne                   Surf Spot
# 178             Rockaway Beach                       Beach
# 179                   Neponsit                       Beach
# 180                Murray Hill           Korean Restaurant
# 181                Floral Park           Indian Restaurant
# 183            Jamaica Estates                Intersection
# 186                 Ravenswood          Italian Restaurant
# 188                  Laurelton        Caribbean Restaurant
# 189                Lefrak City              Cosmetics Shop
# 190               Belle Harbor                       Beach
# 196       Forest Hills Gardens                      Bakery
# 197                 St. George              Clothing Store
# 200                   Rosebank          Mexican Restaurant
# 201              West Brighton                 Coffee Shop
# 211                   New Dorp          Italian Restaurant
# 213                Great Kills          Italian Restaurant
# 217                Tottenville      Thrift / Vintage Store
# 218              Tompkinsville                        Park
# 219                Silver Lake                Burger Joint
# 220                  Sunnyside                 Pizza Place
# 225                Westerleigh                  Baby Store
# 229                   Grasmere                    Bus Stop
# 235                Bay Terrace              Clothing Store
# 239                 Charleston              Cosmetics Shop
# 244                    Chelsea                 Coffee Shop
# 247              Carnegie Hill                 Pizza Place
# 248                       Noho          Italian Restaurant
# 249               Civic Center        Gym / Fitness Center
# 250              Midtown South           Korean Restaurant
# 251              Richmond Town          Italian Restaurant
# 252                Shore Acres          Italian Restaurant
# 253                    Clifton               Grocery Store
# 254                    Concord         Peruvian Restaurant
# 255               Emerson Hill  Construction & Landscaping
# 265                    Pomonok                        Park
# 271               Sutton Place        Gym / Fitness Center
# 272              Hunters Point                        Café
# 273                 Turtle Bay          Italian Restaurant
# 274                 Tudor City                        Park
# 275            Stuyvesant Town                         Bar
# 276                   Flatiron        Gym / Fitness Center
# 277          Sunnyside Gardens                         Bar
# 279               Fulton Ferry                        Park
# 280               Vinegar Hill                  Food Truck
# 281                 Weeksville               Grocery Store
# 283                      Dumbo                        Park
# 287                Egbertville          Italian Restaurant
# 288                    Roxbury                       Beach
# 290             Middle Village                      Bakery
# 292            Lighthouse Hill                  Art Museum
# 294                      Malba                   Rest Area
# 301               Hudson Yards                        Café
# 302                    Hammels                       Beach
# 303                  Bayswater                        Park
# 304               Queensbridge                       Hotel
#
#            2nd Most Common Venue          3rd Most Common Venue  \
# 3                     Playground                          Plaza
# 9                      Nightclub           Caribbean Restaurant
# 12                 Grocery Store             Seafood Restaurant
# 22           Peruvian Restaurant                        Brewery
# 24            Spanish Restaurant                         Bakery
# 27     South American Restaurant                  Boat or Ferry
# 28                 Deli / Bodega            American Restaurant
# 29                    Comic Shop                     Playground
# 46                           Spa                Thai Restaurant
# 47                Ice Cream Shop                     Donut Shop
# 49                   Pizza Place                    Coffee Shop
# 51   Eastern European Restaurant                          Beach
# 52            Turkish Restaurant                 Sandwich Place
# 57               Thai Restaurant                    Pizza Place
# 58                          Park                           Café
# 59            Mexican Restaurant                   Cocktail Bar
# 60                          Park                  Moving Target
# 61                    Bagel Shop                            Bar
# 62            Mexican Restaurant                    Coffee Shop
# 63                   Pizza Place                           Café
# 64                          Park             Italian Restaurant
# 65            Italian Restaurant                    Pizza Place
# 66                   Coffee Shop                   Cocktail Bar
# 67           American Restaurant                           Park
# 68        Furniture / Home Store             Italian Restaurant
# 69                   Pizza Place                      Wine Shop
# 70                   Coffee Shop            American Restaurant
# 76                          Food                           Pool
# 78                      Pharmacy           Caribbean Restaurant
# 81                   Golf Course                     Bagel Shop
# 84                   Pizza Place                      Wine Shop
# 85                   Bus Station                   Home Service
# 86                Sandwich Place                    Coffee Shop
# 87                   Coffee Shop         Furniture / Home Store
# 88                        Bakery                    Pizza Place
# 91                    Donut Shop                     Playground
# 95                 Deli / Bodega                   Cocktail Bar
# 96                   Pizza Place                  Jewelry Store
# 97           American Restaurant                    Coffee Shop
# 98              Sushi Restaurant  Paper / Office Supplies Store
# 99                          Bank                 Sandwich Place
# 100                 Cocktail Bar                         Bakery
# 101                       Bakery                  Grocery Store
# 102           Mexican Restaurant                         Lounge
# 103                         Café             Mexican Restaurant
# 104           Italian Restaurant            Fried Chicken Joint
# 105         Gym / Fitness Center              French Restaurant
# 106                       Bakery                  Deli / Bodega
# 107                      Exhibit                    Art Gallery
# 108           Italian Restaurant                            Gym
# 109           Italian Restaurant                    Pizza Place
# 110               Sandwich Place                           Park
# 111                     Wine Bar                            Bar
# 112                      Theater                           Café
# 113         Gym / Fitness Center                            Spa
# 114                  Coffee Shop                   Cocktail Bar
# 115                  Coffee Shop            Japanese Restaurant
# 116           Italian Restaurant                 Ice Cream Shop
# 117             Sushi Restaurant                 Clothing Store
# 118               Ice Cream Shop                       Wine Bar
# 119                         Café             Chinese Restaurant
# 120          American Restaurant                           Café
# 121                         Café                          Hotel
# 122                     Boutique                  Women's Store
# 123               Cosmetics Shop        New American Restaurant
# 124                  Pizza Place                    Coffee Shop
# 125                         Park                    Coffee Shop
# 126                          Bar                     Bagel Shop
# 127                  Coffee Shop                          Hotel
# 128                    Wine Shop                    Pizza Place
# 129    Middle Eastern Restaurant                     Hookah Bar
# 130              Thai Restaurant                         Bakery
# 131    South American Restaurant            Peruvian Restaurant
# 132           Mexican Restaurant             Chinese Restaurant
# 133                   Bagel Shop                           Bank
# 138              Bubble Tea Shop             Chinese Restaurant
# 139                        Hotel                            Bar
# 140           Italian Restaurant                        Theater
# 143            Mobile Phone Shop                         Bakery
# 145               Sandwich Place                     Donut Shop
# 151                  Pizza Place             Mexican Restaurant
# 152           Athletics & Sports         Furniture / Home Store
# 153           Italian Restaurant              Korean Restaurant
# 160               Sandwich Place             Mexican Restaurant
# 163          Fried Chicken Joint                 Baseball Field
# 168               Cosmetics Shop                      Nightclub
# 173                   Food Truck                  Deli / Bodega
# 175                  Supermarket                     Donut Shop
# 177                Metro Station                 Sandwich Place
# 178               Ice Cream Shop                      BBQ Joint
# 179                    Beach Bar                  Women's Store
# 180                  Coffee Shop            Japanese Restaurant
# 181                   Dosa Place               Basketball Court
# 183            Indian Restaurant                        Dog Run
# 186           Chinese Restaurant                  Grocery Store
# 188               Cosmetics Shop                  Train Station
# 189                       Bakery               Department Store
# 190                Deli / Bodega                            Spa
# 196                   Donut Shop                     Playground
# 197                  Pizza Place             Italian Restaurant
# 200                Grocery Store             Italian Restaurant
# 201           Italian Restaurant            American Restaurant
# 211                  Pizza Place             Salon / Barbershop
# 213                          Bar                    Pizza Place
# 217           Italian Restaurant                  Deli / Bodega
# 218                          Pub                      Rock Club
# 219          American Restaurant                    Golf Course
# 220           Italian Restaurant                        Theater
# 225            Convenience Store                         Arcade
# 229                         Bank                         Bakery
# 235                  Supermarket                     Donut Shop
# 239                Big Box Store                  Women's Store
# 244           Italian Restaurant                 Ice Cream Shop
# 247                  Coffee Shop                           Café
# 248            French Restaurant                   Cocktail Bar
# 249                  Coffee Shop             Italian Restaurant
# 250                    Hotel Bar                          Hotel
# 251                   Bagel Shop                 History Museum
# 252                     Bus Stop                   Intersection
# 253                Train Station             Chinese Restaurant
# 254                Deli / Bodega                     Bagel Shop
# 255             Sculpture Garden                           Food
# 265          Japanese Restaurant                     Playground
# 271           Italian Restaurant              Indian Restaurant
# 272           Italian Restaurant            Japanese Restaurant
# 273             Sushi Restaurant                     Steakhouse
# 274                         Café             Mexican Restaurant
# 275                   Playground                  Boat or Ferry
# 276                          Gym                    Yoga Studio
# 277                Grocery Store            American Restaurant
# 279          American Restaurant                 Scenic Lookout
# 280                  Art Gallery                      Wine Shop
# 281                         Café                 Discount Store
# 283                  Coffee Shop                 Scenic Lookout
# 287               Clothing Store                     Bagel Shop
# 288               Baseball Field                  Deli / Bodega
# 290                        Diner                 Sandwich Place
# 292           Italian Restaurant                          Trail
# 294                 Tennis Court                    Fish Market
# 301          American Restaurant             Italian Restaurant
# 302                     Building                     Food Truck
# 303                   Playground                   Tennis Court
# 304               Sandwich Place                           Park
#
#              4th Most Common Venue          5th Most Common Venue
# 3                    Women's Store              Fish & Chips Shop
# 9                       Soup Place                    Flea Market
# 12          Thrift / Vintage Store                 Baseball Field
# 22                   Grocery Store                     Donut Shop
# 24                  Farmers Market                      BBQ Joint
# 27                  Scenic Lookout                  Grocery Store
# 28                      Sports Bar                 Baseball Field
# 29                    Liquor Store                    Flea Market
# 46             American Restaurant             Chinese Restaurant
# 47                Sushi Restaurant             Chinese Restaurant
# 49                    Cocktail Bar                    Yoga Studio
# 51                      Restaurant                           Bank
# 52                Department Store                           Café
# 57              Mexican Restaurant                 Ice Cream Shop
# 58                           Plaza                     Bagel Shop
# 59                       Wine Shop                         Bakery
# 60           Performing Arts Venue             Chinese Restaurant
# 61                     Pizza Place                      Pet Store
# 62                   Deli / Bodega                    Pizza Place
# 63                     Coffee Shop                            Bar
# 64                   Deli / Bodega                            Gym
# 65                      Playground                    Coffee Shop
# 66                     Pizza Place                         Bakery
# 67                             Bar                    Art Gallery
# 68                     Coffee Shop                     Food Truck
# 69                     Coffee Shop                    Flower Shop
# 70                     Pizza Place             Italian Restaurant
# 76                   Women's Store                    Fish Market
# 78             Monument / Landmark                     Food Court
# 81                      Playground                  Grocery Store
# 84              Mexican Restaurant                    Yoga Studio
# 85                           Beach                            Spa
# 86               French Restaurant                    Pizza Place
# 87                  Sandwich Place              French Restaurant
# 88            Caribbean Restaurant                      Wine Shop
# 91              Athletics & Sports                 Baseball Field
# 95                     Coffee Shop                   Concert Hall
# 96   Vegetarian / Vegan Restaurant            American Restaurant
# 97                     Pizza Place                    Yoga Studio
# 98            Gym / Fitness Center                            Gym
# 99            Gym / Fitness Center             Italian Restaurant
# 100                Bubble Tea Shop            American Restaurant
# 101              Mobile Phone Shop                    Coffee Shop
# 102                    Pizza Place             Spanish Restaurant
# 103                    Coffee Shop                  Deli / Bodega
# 104                           Park             Seafood Restaurant
# 105             African Restaurant                     Public Art
# 106      Latin American Restaurant                Thai Restaurant
# 107                         Bakery           Gym / Fitness Center
# 108                            Bar                    Pizza Place
# 109               Sushi Restaurant                   Burger Joint
# 110                       Bus Line                    Dry Cleaner
# 111                    Coffee Shop  Vegetarian / Vegan Restaurant
# 112                   Concert Hall             Italian Restaurant
# 113            American Restaurant             Italian Restaurant
# 114                 Clothing Store                        Theater
# 115                          Hotel                            Bar
# 116                         Bakery                      Nightclub
# 117             Seafood Restaurant                 Cosmetics Shop
# 118                    Pizza Place             Chinese Restaurant
# 119                    Pizza Place                        Theater
# 120             Italian Restaurant                            Spa
# 121                 Clothing Store                 Sandwich Place
# 122                    Art Gallery                     Shoe Store
# 123                       Wine Bar                           Park
# 124                    Yoga Studio                            Bar
# 125            American Restaurant                  Deli / Bodega
# 126                    Pizza Place                  Grocery Store
# 127                  Memorial Site                 Clothing Store
# 128            American Restaurant                          Hotel
# 129               Greek Restaurant             Seafood Restaurant
# 130            Filipino Restaurant      Latin American Restaurant
# 131                         Bakery                Thai Restaurant
# 132      South American Restaurant                Bubble Tea Shop
# 133                       Pharmacy                 Sandwich Place
# 138               Asian Restaurant              Korean Restaurant
# 139             Mexican Restaurant                           Café
# 140                 Discount Store      South American Restaurant
# 143                           Bank                  Grocery Store
# 145               Sushi Restaurant                    Pizza Place
# 151               Sushi Restaurant                            Pub
# 152                   Noodle House                    Supermarket
# 153                  Deli / Bodega                            Spa
# 160            Fried Chicken Joint               Department Store
# 163                  Shopping Mall                  Grocery Store
# 168                   Liquor Store                    Flower Shop
# 173                 Cosmetics Shop               Sushi Restaurant
# 175             Italian Restaurant                 Lingerie Store
# 177                Thai Restaurant                          Beach
# 178                  Metro Station      Latin American Restaurant
# 179                    Flower Shop             Falafel Restaurant
# 180                          Hotel                            Bar
# 181                     Nail Salon                     Hobby Shop
# 183                  Women's Store                    Flea Market
# 186              Food & Drink Shop               Sushi Restaurant
# 188                           Park                  Women's Store
# 189                            Spa        Health & Beauty Service
# 190                     Bagel Shop                            Pub
# 196             Mexican Restaurant               Tapas Restaurant
# 197                            Bar                 Scenic Lookout
# 200                 Discount Store                          Beach
# 201                       Pharmacy                            Bar
# 211                         Bakery                           Bank
# 213                   Liquor Store                  Train Station
# 217             Mexican Restaurant                 Cosmetics Shop
# 218          Sri Lankan Restaurant                        Brewery
# 219                    Art Gallery                          Plaza
# 220                 Discount Store      South American Restaurant
# 225                    Comedy Club                  Women's Store
# 229                     Bagel Shop             Italian Restaurant
# 235             Italian Restaurant                 Lingerie Store
# 239                   Burger Joint           Gym / Fitness Center
# 244                         Bakery                      Nightclub
# 247                 Cosmetics Shop            Japanese Restaurant
# 248                    Art Gallery                      Bookstore
# 249                          Hotel              French Restaurant
# 250            Japanese Restaurant                    Coffee Shop
# 251                            Spa                           Café
# 252                  Deli / Bodega                            Bar
# 253                   Burger Joint                    Pizza Place
# 254                    Supermarket                  Train Station
# 255                            Gym                  Women's Store
# 265                    Supermarket                  Bowling Alley
# 271         Furniture / Home Store                            Gym
# 272                       Wine Bar                      Wine Shop
# 273                    Coffee Shop                       Wine Bar
# 274               Greek Restaurant               Sushi Restaurant
# 275                           Park                       Fountain
# 276            Japanese Restaurant            American Restaurant
# 277                Thai Restaurant              Korean Restaurant
# 279                           Café                     Playground
# 280                           Café                    Coffee Shop
# 281                  Metro Station                   Cocktail Bar
# 283                           Café                      Bookstore
# 287                 Cosmetics Shop     Construction & Landscaping
# 288                      Irish Pub                          Trail
# 290               Sushi Restaurant                     Playground
# 292                            Spa                           Café
# 294                    Event Space                        Exhibit
# 301           Gym / Fitness Center             Spanish Restaurant
# 302           Fast Food Restaurant                     Shoe Store
# 303                  Women's Store                  Event Service
# 304                      Hotel Bar                     Hotel Pool
